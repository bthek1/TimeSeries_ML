# %% [raw]
# ---
# description: 'Assumption: consumption = func(individual components, future weather,
#   future humidity)'
# output-file: individual_model_aircon.html
# skip_exec: true
# skip_showdoc: true
# title: Aircon Model
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Get Data

# %%
#|eval: false
import influxdb_client
from influxdb_client.client.write_api import SYNCHRONOUS
import pandas as pd

import warnings
from influxdb_client.client.warnings import MissingPivotFunction

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

warnings.simplefilter("ignore", MissingPivotFunction)

# %%
#|eval: false
result = query_api.query_data_frame(org=org, query=query)
result.columns
# Out:
# Index(['result', 'table', '_start', '_stop', '_time', '_value', '_field',
#        '_measurement', 'device', 'sensor', 'units'],
#       dtype='object')

# %%
#|eval: false
result.shape
# Out:
# (4182, 11)

# %% [markdown]
#  result.to_csv(f'./Data/energy_info.csv', index=False) #save the data as a csv

# %%
result.drop(['result', 'table', '_field', '_start', '_stop', '_measurement', 'units', 'device'], axis=1, inplace=True)

# %%
#|eval: false
result.head()
# Out:
#                       _time      _value  sensor
# 0 2023-03-02 00:00:00+00:00   12.888000  Aircon
# 1 2023-03-03 00:00:00+00:00  121.541007  Aircon
# 2 2023-03-04 00:00:00+00:00  222.993806  Aircon
# 3 2023-03-05 00:00:00+00:00  118.435757  Aircon
# 4 2023-03-06 00:00:00+00:00  238.721389  Aircon

# %%
#|eval: false
result.columns
# Out:
# Index(['_time', '_value', 'sensor'], dtype='object')

# %% [markdown]
# ## Energy in Wide Form

# %%
#|eval: false
wide_df = result.pivot(index='_time', columns='sensor', values='_value')
# Reset the index to make 'id' a regular column
wide_df.reset_index(inplace=True)

wide_df.columns
# Out:
# Index(['_time', 'Aircon', 'Consumption', 'ConsumptionNet', 'Export', 'Fridge',
#        'Garage', 'Hotwater', 'HouseBoardOutside', 'HouseBoardOutsideR',
#        'HouseBoardR', 'Import', 'Lights', 'Net', 'OvenStove', 'Powerpoints',
#        'Production', 'Unmonitored'],
#       dtype='object', name='sensor')

# %%
wide_df['_time'] = pd.to_datetime(wide_df['_time']).dt.tz_localize(None)
wide_df.drop(['Unmonitored', 'Consumption', 'ConsumptionNet'], axis = 1, inplace=True)
wide_df.rename(columns={'_time':'ds'}, inplace=True)
# Delete the last row
wide_df = wide_df.drop(wide_df.index[-1])

# %%
wide_df_new = pd.DataFrame()
for column in wide_df.columns:
    wide_df_new[f'{column}'] = wide_df[f'{column}'].interpolate()

wide_df = pd.DataFrame(wide_df_new)
wide_df.columns
# Out:
# Index(['ds', 'Aircon', 'Export', 'Fridge', 'Garage', 'Hotwater',
#        'HouseBoardOutside', 'HouseBoardOutsideR', 'HouseBoardR', 'Import',
#        'Lights', 'Net', 'OvenStove', 'Powerpoints', 'Production'],
#       dtype='object')

# %%
wide_df.tail()
# Out:
#             ds    Aircon      Export     Fridge     Garage  Hotwater  \
# 240 2023-10-28  8.578005  180.242247  25.492343  24.017087  0.530865
# 241 2023-10-29  8.661682  806.610093  19.634587   2.731102  0.192283
# 242 2023-10-30  8.603354  757.601472  27.081000   0.983716  0.183639
# 243 2023-10-31  9.032917  803.841970  35.649472  11.163953  0.269313
# 244 2023-11-01  8.743938  898.594991  30.389375   3.655479  0.189410
#
#      HouseBoardOutside  HouseBoardOutsideR  HouseBoardR     Import     Lights  \
# 240         999.775552          333.258545   366.408449  71.876417  80.009421
# 241         530.312474          176.770805   201.397413   1.974071  60.108551
# 242         788.486015          262.828480   290.616882   3.378339  66.827993
# 243         901.165305          300.388379   319.795146   5.027126  67.972347
# 244         623.050504          207.683462   245.486118   2.309883  50.624125
#
#             Net  OvenStove  Powerpoints   Production
# 240 -108.365830  66.086281   176.392548   491.748285
# 241 -804.636021   1.253300   103.451046  1017.375874
# 242 -754.223132   1.356785   178.170521  1052.272015
# 243 -798.814844  30.217549   166.649785  1142.661342
# 244 -896.285107   0.213375   145.941312  1134.978184

# %%
def data_scaler(df):
    import pandas as pd
    from sklearn.preprocessing import MinMaxScaler

    numeric_columns = df.select_dtypes(include=['number']).columns
        
    # Scale numeric columns
    df[numeric_columns] = MinMaxScaler().fit_transform(df[numeric_columns])

    return df

# %%
def long_form(df_plot):
    return df_plot.melt('ds', var_name='unique_id', value_name='y')

def altair_plot(df_plot): 
    import altair as alt
    highlight = alt.selection_point(on='mouseover', fields=['unique_id'], bind='legend', nearest=True)

    base = alt.Chart(df_plot).encode(
        x='ds:T',
        y='y:Q',
        color='unique_id:N'
    )

    points = base.mark_circle().encode(
        opacity=alt.value(0)
    ).add_params(
        highlight
    ).properties(
        width=1000
    )

    lines = base.mark_line().encode(
        size=alt.condition(~highlight, alt.value(1), alt.value(3))
    )

    return points + lines

# %%
wide_df = data_scaler(wide_df)
wide_df.tail()
# Out:
#             ds    Aircon    Export    Fridge    Garage  Hotwater  \
# 240 2023-10-28  0.000327  0.087269  0.054518  0.475787  0.000988
# 241 2023-10-29  0.000459  0.390543  0.008991  0.049113  0.000167
# 242 2023-10-30  0.000367  0.366814  0.066865  0.014087  0.000146
# 243 2023-10-31  0.001045  0.389203  0.133461  0.218148  0.000354
# 244 2023-11-01  0.000589  0.435080  0.092579  0.067642  0.000160
#
#      HouseBoardOutside  HouseBoardOutsideR  HouseBoardR    Import    Lights  \
# 240           0.441317            0.270647     0.263152  0.098826  0.397064
# 241           0.155476            0.095349     0.096613  0.001842  0.287229
# 242           0.312670            0.191751     0.186659  0.003790  0.324314
# 243           0.381277            0.233826     0.216107  0.006078  0.330630
# 244           0.211942            0.129978     0.141110  0.002308  0.234883
#
#           Net  OvenStove  Powerpoints  Production
# 240  0.702175   0.217335     0.451213    0.164710
# 241  0.452268   0.003559     0.195780    0.385757
# 242  0.470363   0.003900     0.457440    0.400433
# 243  0.454358   0.099064     0.417095    0.438445
# 244  0.419373   0.000130     0.344577    0.435214

# %%
df = long_form(wide_df)
wide_df.rename(columns={'Aircon': 'y'}, inplace=True)
wide_df['unique_id'] = 'Aircon'
df.head()
# Out:
#           ds unique_id         y
# 0 2023-03-02    Aircon  0.007134
# 1 2023-03-03    Aircon  0.178748
# 2 2023-03-04    Aircon  0.338990
# 3 2023-03-05    Aircon  0.173844
# 4 2023-03-06    Aircon  0.363831

# %% [markdown]
# ## Weather data

# %%
import pandas as pd
path = 'Data'
name = 'weather'

weather_df = pd.read_csv(f'{path}/{name}.csv')
weather_df.head()
# Out:
#                  ds  temp_c  is_day  wind_kph  wind_degree  pressure_mb  \
# 0  2023-01-01 00:00    21.6       0      12.6          126       1013.0
# 1  2023-01-01 01:00    21.3       0      11.9          133       1013.0
# 2  2023-01-01 02:00    21.1       0      11.2          140       1012.0
# 3  2023-01-01 03:00    20.8       0      10.4          147       1012.0
# 4  2023-01-01 04:00    21.0       0      10.6          144       1012.0
#
#    precip_mm  humidity  cloud  feelslike_c  windchill_c  heatindex_c  \
# 0        0.0        84     73         21.6         21.6         24.4
# 1        0.0        85     77         21.3         21.3         24.3
# 2        0.0        86     80         21.1         21.1         24.2
# 3        0.0        88     84         20.8         20.8         20.8
# 4        0.0        86     84         21.0         21.0         21.0
#
#    dewpoint_c  chance_of_rain  vis_km  gust_kph   uv
# 0        18.7               0    10.0      19.8  1.0
# 1        18.7               0    10.0      18.7  1.0
# 2        18.7               0    10.0      17.6  1.0
# 3        18.7               0    10.0      16.6  1.0
# 4        18.6               0    10.0      16.3  1.0

# %%
weather_df = data_scaler(weather_df)

# %%
def data_day_avg(weather_df):
    from tqdm.notebook import tqdm
    avg_df = pd.DataFrame()
    dates = pd.to_datetime(weather_df['ds']).dt.date.unique()
    
    for date in tqdm(dates):
        filtered_df = weather_df[pd.to_datetime(weather_df['ds']).dt.date == date]
        ds = filtered_df.pop('ds')

        filtered_df = pd.DataFrame(filtered_df.mean()).T
        filtered_df

        filtered_df.insert(0, 'ds', date)

        avg_df = pd.concat([avg_df, filtered_df], ignore_index=True)
    
    return avg_df

# %%
weather_avg_df = data_day_avg(weather_df)
# Out:
#   0%|          | 0/344 [00:00<?, ?it/s]

# %%
weather_avg_df['ds'] = pd.to_datetime(weather_avg_df['ds'])

# %%
weather_avg_df
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 0   2023-01-01  0.566503  0.583333  0.459098     0.345636     0.428728
# 1   2023-01-02  0.554902  0.583333  0.451453     0.396936     0.359649
# 2   2023-01-03  0.582516  0.583333  0.263889     0.415506     0.258772
# 3   2023-01-04  0.650490  0.583333  0.313073     0.382660     0.163377
# 4   2023-01-05  0.654575  0.583333  0.257518     0.506267     0.166667
# ..         ...       ...       ...       ...          ...          ...
# 339 2023-12-06  0.580556  0.583333  0.254077     0.264740     0.558114
# 340 2023-12-07  0.605065  0.583333  0.266565     0.202066     0.565789
# 341 2023-12-08  0.618954  0.583333  0.349261     0.251625     0.575658
# 342 2023-12-09  0.612582  0.583333  0.362768     0.190460     0.544956
# 343 2023-12-10  0.630556  0.583333  0.513507     0.233751     0.530702
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 0     0.000895  0.670886  0.583750     0.516791     0.595085     0.512881
# 1     0.001253  0.602848  0.409167     0.499005     0.584249     0.486067
# 2     0.000000  0.584916  0.287917     0.525746     0.610043     0.502366
# 3     0.000895  0.687764  0.196250     0.608582     0.673535     0.609621
# 4     0.026859  0.735232  0.700417     0.629726     0.677350     0.608701
# ..         ...       ...       ...          ...          ...          ...
# 339   0.000000  0.608650  0.174583     0.519527     0.608364     0.515116
# 340   0.000000  0.582806  0.050000     0.543532     0.631258     0.533386
# 341   0.000018  0.626582  0.342083     0.561816     0.644078     0.555205
# 342   0.000107  0.577532  0.497500     0.564179     0.638584     0.539432
# 343   0.000233  0.515295  0.537500     0.571269     0.655067     0.546924
#
#      dewpoint_c  chance_of_rain    vis_km  gust_kph        uv
# 0      0.778121             0.0  1.000000  0.434678  0.422619
# 1      0.725707             0.0  1.000000  0.434844  0.428571
# 2      0.738663             0.0  1.000000  0.283533  0.452381
# 3      0.866902             0.0  0.994792  0.305777  0.500000
# 4      0.911808             0.0  0.989583  0.288098  0.416667
# ..          ...             ...       ...       ...       ...
# 339    0.745878             0.0  1.000000  0.214558  0.470238
# 340    0.748233             0.0  1.000000  0.222693  0.476190
# 341    0.795200             0.0  1.000000  0.285940  0.476190
# 342    0.757509             0.0  1.000000  0.308267  0.428571
# 343    0.730271             0.0  1.000000  0.426627  0.452381
#
# [344 rows x 17 columns]

# %%
#|eval: false
(
    wide_df[['y']].plot(title='Aircon')
)
# Out:
# <Axes: title={'center': 'Aircon'}>

# %%
#|eval: false
from statsforecast import StatsForecast

# %%
#|eval: false
from pylab import rcParams
rcParams['figure.figsize'] = (15,4)
StatsForecast.plot(df, engine='plotly')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
wide_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ds                  245 non-null    datetime64[ns]
#  1   y                   245 non-null    float64
#  2   Export              245 non-null    float64
#  3   Fridge              245 non-null    float64
#  4   Garage              245 non-null    float64
#  5   Hotwater            245 non-null    float64
#  6   HouseBoardOutside   161 non-null    float64
#  7   HouseBoardOutsideR  245 non-null    float64
#  8   HouseBoardR         245 non-null    float64
#  9   Import              245 non-null    float64
#  10  Lights              245 non-null    float64
#  11  Net                 245 non-null    float64
#  12  OvenStove           245 non-null    float64
#  13  Powerpoints         245 non-null    float64
#  14  Production          245 non-null    float64
#  15  unique_id           245 non-null    object
# dtypes: datetime64[ns](1), float64(14), object(1)
# memory usage: 30.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3430 entries, 0 to 3429
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ds         3430 non-null   datetime64[ns]
#  1   unique_id  3430 non-null   object
#  2   y          3346 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 80.5+ KB

# %%
weather_avg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ds              344 non-null    datetime64[ns]
#  1   temp_c          344 non-null    float64
#  2   is_day          344 non-null    float64
#  3   wind_kph        344 non-null    float64
#  4   wind_degree     344 non-null    float64
#  5   pressure_mb     344 non-null    float64
#  6   precip_mm       344 non-null    float64
#  7   humidity        344 non-null    float64
#  8   cloud           344 non-null    float64
#  9   feelslike_c     344 non-null    float64
#  10  windchill_c     344 non-null    float64
#  11  heatindex_c     344 non-null    float64
#  12  dewpoint_c      344 non-null    float64
#  13  chance_of_rain  344 non-null    float64
#  14  vis_km          344 non-null    float64
#  15  gust_kph        344 non-null    float64
#  16  uv              344 non-null    float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 45.8 KB

# %%
date_range_start, date_range_end  = wide_df['ds'].min(), wide_df['ds'].max()
# Filter rows between the start and end dates
weather_avg_filtered_df = weather_avg_df[(weather_avg_df['ds'] >= date_range_start) & (weather_avg_df['ds'] <= date_range_end)]
weather_avg_filtered_df
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 60  2023-03-02  0.644444  0.541667  0.294980     0.153784     0.344298
# 61  2023-03-03  0.603268  0.541667  0.483563     0.386142     0.403509
# 62  2023-03-04  0.561765  0.541667  0.574669     0.433612     0.425439
# 63  2023-03-05  0.598039  0.541667  0.372324     0.350627     0.427632
# 64  2023-03-06  0.629575  0.541667  0.313073     0.290854     0.417763
# ..         ...       ...       ...       ...          ...          ...
# 300 2023-10-28  0.379575  0.541667  0.700051     0.446611     0.708333
# 301 2023-10-29  0.382516  0.541667  0.383028     0.320682     0.656798
# 302 2023-10-30  0.441340  0.583333  0.396152     0.435237     0.562500
# 303 2023-10-31  0.550163  0.583333  0.489424     0.549559     0.442982
# 304 2023-11-01  0.510784  0.583333  0.561672     0.445218     0.505482
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 60    0.001056  0.675633  0.345417     0.609826     0.667888     0.594374
# 61    0.002131  0.682489  0.579167     0.572388     0.629426     0.548107
# 62    0.000161  0.604430  0.364583     0.509204     0.590659     0.491982
# 63    0.000358  0.603903  0.401250     0.542537     0.624542     0.531677
# 64    0.000358  0.608650  0.157500     0.568284     0.653999     0.557965
# ..         ...       ...       ...          ...          ...          ...
# 300   0.000233  0.500000  0.389167     0.351741     0.414835     0.327681
# 301   0.000125  0.524789  0.433750     0.347637     0.423230     0.329390
# 302   0.000000  0.583861  0.181250     0.403483     0.478327     0.373686
# 303   0.000000  0.570675  0.025417     0.492537     0.579976     0.467140
# 304   0.000340  0.599156  0.480000     0.458209     0.543040     0.435594
#
#      dewpoint_c  chance_of_rain  vis_km  gust_kph        uv
# 60     0.845112             0.0     1.0  0.250332  0.470238
# 61     0.821555             0.0     1.0  0.432022  0.380952
# 62     0.734982             0.0     1.0  0.485309  0.422619
# 63     0.761042             0.0     1.0  0.319804  0.428571
# 64     0.785925             0.0     1.0  0.263363  0.476190
# ..          ...             ...     ...       ...       ...
# 300    0.497939             0.0     1.0  0.588811  0.345238
# 301    0.525324             0.0     1.0  0.328934  0.345238
# 302    0.611307             0.0     1.0  0.340139  0.416667
# 303    0.687132             0.0     1.0  0.470286  0.464286
# 304    0.685218             0.0     1.0  0.467795  0.404762
#
# [245 rows x 17 columns]

# %%
altair_plot(df)
# Out:
# alt.LayerChart(...)

# %%
weather_avg_df_plot = long_form(weather_avg_filtered_df)
altair_plot(weather_avg_df_plot)
# Out:
# alt.LayerChart(...)

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
wide_df["y"]
# Out:
# 0      0.007134
# 1      0.178748
# 2      0.338990
# 3      0.173844
# 4      0.363831
#          ...
# 240    0.000327
# 241    0.000459
# 242    0.000367
# 243    0.001045
# 244    0.000589
# Name: y, Length: 245, dtype: float64

# %%
def augmented_dickey_fuller_test(series , column_name):
    from statsmodels.tsa.stattools import adfuller
    print (f'Dickey-Fuller test results for columns: {column_name}')
    dftest = adfuller(series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','No Lags Used','Number of observations used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    if dftest[1] <= 0.05:
        print("Conclusion:====>")
        print("Reject the null hypothesis")
        print("The data is stationary")
    else:
        print("Conclusion:====>")
        print("The null hypothesis cannot be rejected")
        print("The data is not stationary")

# %%
augmented_dickey_fuller_test(wide_df["y"],'Ads')
# Out:
# Dickey-Fuller test results for columns: Ads
# Test Statistic                  -3.009405
# p-value                          0.034025
# No Lags Used                    12.000000
# Number of observations used    232.000000
# Critical Value (1%)             -3.458855
# Critical Value (5%)             -2.874080
# Critical Value (10%)            -2.573453
# dtype: float64
# Conclusion:====>
# Reject the null hypothesis
# The data is stationary

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)

plot_acf(wide_df["y"],  lags=28, ax=axs[0],color="fuchsia")
axs[0].set_title("Autocorrelation");

plot_pacf(wide_df["y"],  lags=28, ax=axs[1],color="lime")
axs[1].set_title('Partial Autocorrelation')

plt.show();

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)

plot_acf(wide_df["y"],  lags=14, ax=axs[0],color="fuchsia")
axs[0].set_title("Autocorrelation");

plot_pacf(wide_df["y"],  lags=14, ax=axs[1],color="lime")
axs[1].set_title('Partial Autocorrelation')

plt.show();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose 
a = seasonal_decompose(wide_df["y"], model = "additive", period=28)
a.plot();

# %% [markdown]
# ## Designing Models

# %%
weather_avg_filtered_df.head()
# Out:
#            ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 60 2023-03-02  0.644444  0.541667  0.294980     0.153784     0.344298
# 61 2023-03-03  0.603268  0.541667  0.483563     0.386142     0.403509
# 62 2023-03-04  0.561765  0.541667  0.574669     0.433612     0.425439
# 63 2023-03-05  0.598039  0.541667  0.372324     0.350627     0.427632
# 64 2023-03-06  0.629575  0.541667  0.313073     0.290854     0.417763
#
#     precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 60   0.001056  0.675633  0.345417     0.609826     0.667888     0.594374
# 61   0.002131  0.682489  0.579167     0.572388     0.629426     0.548107
# 62   0.000161  0.604430  0.364583     0.509204     0.590659     0.491982
# 63   0.000358  0.603903  0.401250     0.542537     0.624542     0.531677
# 64   0.000358  0.608650  0.157500     0.568284     0.653999     0.557965
#
#     dewpoint_c  chance_of_rain  vis_km  gust_kph        uv
# 60    0.845112             0.0     1.0  0.250332  0.470238
# 61    0.821555             0.0     1.0  0.432022  0.380952
# 62    0.734982             0.0     1.0  0.485309  0.422619
# 63    0.761042             0.0     1.0  0.319804  0.428571
# 64    0.785925             0.0     1.0  0.263363  0.476190

# %%
wide_df = pd.merge(wide_df, weather_avg_filtered_df, on='ds', how='outer')

# %%
wide_df.head()
# Out:
#           ds         y    Export    Fridge    Garage  Hotwater  \
# 0 2023-03-02  0.007134  0.016595  0.814609  0.003794  0.000287
# 1 2023-03-03  0.178748  0.165011  0.669709  0.015031  0.000143
# 2 2023-03-04  0.338990  0.294620  0.686509  0.059559  0.000460
# 3 2023-03-05  0.173844  0.302607  0.701288  0.009916  0.000256
# 4 2023-03-06  0.363831  0.381220  0.773714  0.008798  0.002112
#
#    HouseBoardOutside  HouseBoardOutsideR  HouseBoardR    Import  ...  \
# 0                NaN            0.356702     0.364385  0.085067  ...
# 1                NaN            0.292065     0.295309  0.296304  ...
# 2                NaN            0.496691     0.501420  0.551547  ...
# 3                NaN            0.419958     0.422212  0.467784  ...
# 4                NaN            0.562640     0.561444  0.600856  ...
#
#    humidity     cloud  feelslike_c  windchill_c  heatindex_c dewpoint_c  \
# 0  0.675633  0.345417     0.609826     0.667888     0.594374   0.845112
# 1  0.682489  0.579167     0.572388     0.629426     0.548107   0.821555
# 2  0.604430  0.364583     0.509204     0.590659     0.491982   0.734982
# 3  0.603903  0.401250     0.542537     0.624542     0.531677   0.761042
# 4  0.608650  0.157500     0.568284     0.653999     0.557965   0.785925
#
#    chance_of_rain  vis_km  gust_kph        uv
# 0             0.0     1.0  0.250332  0.470238
# 1             0.0     1.0  0.432022  0.380952
# 2             0.0     1.0  0.485309  0.422619
# 3             0.0     1.0  0.319804  0.428571
# 4             0.0     1.0  0.263363  0.476190
#
# [5 rows x 32 columns]

# %%
horizon = 10

train_size = len(wide_df) - horizon
train, test = wide_df[:train_size], wide_df[train_size:]


wide_df.shape, train.shape, test.shape
# Out:
# ((245, 32), (235, 32), (10, 32))

# %%
futr_df=weather_avg_filtered_df[train_size:]
futr_df['unique_id'] = 'Aircon'

# %%
futr_df.head()
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 295 2023-10-23  0.560784  0.500000  0.579256     0.550836     0.439693
# 296 2023-10-24  0.550490  0.541667  0.571738     0.437210     0.500000
# 297 2023-10-25  0.558660  0.541667  0.585117     0.546657     0.482456
# 298 2023-10-26  0.495261  0.541667  0.518349     0.551996     0.493421
# 299 2023-10-27  0.309314  0.541667  0.621814     0.516481     0.633772
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 295   0.000000  0.614979  0.075000     0.509328     0.589896     0.485279
# 296   0.000430  0.684599  0.150833     0.503483     0.580128     0.486593
# 297   0.000000  0.656646  0.073750     0.511070     0.588217     0.487119
# 298   0.005766  0.684072  0.593333     0.449627     0.528541     0.422581
# 299   0.008792  0.767932  0.862500     0.289552     0.355311     0.249211
#
#      dewpoint_c  chance_of_rain    vis_km  gust_kph        uv unique_id
# 295    0.734246             0.0  1.000000  0.512699  0.392857    Aircon
# 296    0.771349             0.0  1.000000  0.495933  0.410714    Aircon
# 297    0.759570             0.0  1.000000  0.513197  0.428571    Aircon
# 298    0.725265             0.0  0.953125  0.448705  0.363095    Aircon
# 299    0.616166             0.0  0.994792  0.573373  0.232143    Aircon

# %%
from neuralforecast import models
models.__all__
# Out:
# ['RNN',
#  'GRU',
#  'LSTM',
#  'TCN',
#  'DeepAR',
#  'DilatedRNN',
#  'MLP',
#  'NHITS',
#  'NBEATS',
#  'NBEATSx',
#  'TFT',
#  'VanillaTransformer',
#  'Informer',
#  'Autoformer',
#  'PatchTST',
#  'FEDformer',
#  'StemGNN',
#  'HINT',
#  'TimesNet']

# %%
from ray import tune

from neuralforecast.core import NeuralForecast
from neuralforecast.auto import AutoMLP
from neuralforecast.models import *

# %%
model_list = [RNN,
 GRU,
 LSTM,
 TCN,
 #DeepAR,  # not good
 DilatedRNN,
 MLP,
 NHITS,
 NBEATS,
 NBEATSx,
 #TFT, # too much GPU
 #VanillaTransformer, # not good
 #Informer,
 #Autoformer,
 #PatchTST, # too much GPU
 #FEDformer, #taken too long
 #StemGNN, #need n_series
 #HINT, #need n_series
 #TimesNet # takes too long
             ]

# %%
wide_df.columns
# Out:
# Index(['ds', 'y', 'Export', 'Fridge', 'Garage', 'Hotwater',
#        'HouseBoardOutside', 'HouseBoardOutsideR', 'HouseBoardR', 'Import',
#        'Lights', 'Net', 'OvenStove', 'Powerpoints', 'Production', 'unique_id',
#        'temp_c', 'is_day', 'wind_kph', 'wind_degree', 'pressure_mb',
#        'precip_mm', 'humidity', 'cloud', 'feelslike_c', 'windchill_c',
#        'heatindex_c', 'dewpoint_c', 'chance_of_rain', 'vis_km', 'gust_kph',
#        'uv'],
#       dtype='object')

# %%
models = [model(input_size=5 * horizon,
                h=horizon,
                max_steps=20,
                hist_exog_list =['Export',
                                ],
                futr_exog_list = ['temp_c', 'is_day', 'wind_kph', 'wind_degree',
                    'pressure_mb', 'precip_mm', 'humidity', 'cloud', 'feelslike_c',
                    'windchill_c', 'heatindex_c', 'dewpoint_c', 'chance_of_rain',
                    'vis_km', 'gust_kph', 'uv']
               ) for model in model_list]
models
# Out:
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# [RNN, GRU, LSTM, TCN, DilatedRNN, MLP, NHITS, NBEATS, NBEATSx]

# %%
nf = NeuralForecast(
    models=models, 
    freq='D')

# %%
train.columns
# Out:
# Index(['ds', 'y', 'Export', 'Fridge', 'Garage', 'Hotwater',
#        'HouseBoardOutside', 'HouseBoardOutsideR', 'HouseBoardR', 'Import',
#        'Lights', 'Net', 'OvenStove', 'Powerpoints', 'Production', 'unique_id',
#        'temp_c', 'is_day', 'wind_kph', 'wind_degree', 'pressure_mb',
#        'precip_mm', 'humidity', 'cloud', 'feelslike_c', 'windchill_c',
#        'heatindex_c', 'dewpoint_c', 'chance_of_rain', 'vis_km', 'gust_kph',
#        'uv'],
#       dtype='object')

# %%
nf.fit(df=train)
# Out:
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
futr_df.head()
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 295 2023-10-23  0.560784  0.500000  0.579256     0.550836     0.439693
# 296 2023-10-24  0.550490  0.541667  0.571738     0.437210     0.500000
# 297 2023-10-25  0.558660  0.541667  0.585117     0.546657     0.482456
# 298 2023-10-26  0.495261  0.541667  0.518349     0.551996     0.493421
# 299 2023-10-27  0.309314  0.541667  0.621814     0.516481     0.633772
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 295   0.000000  0.614979  0.075000     0.509328     0.589896     0.485279
# 296   0.000430  0.684599  0.150833     0.503483     0.580128     0.486593
# 297   0.000000  0.656646  0.073750     0.511070     0.588217     0.487119
# 298   0.005766  0.684072  0.593333     0.449627     0.528541     0.422581
# 299   0.008792  0.767932  0.862500     0.289552     0.355311     0.249211
#
#      dewpoint_c  chance_of_rain    vis_km  gust_kph        uv unique_id
# 295    0.734246             0.0  1.000000  0.512699  0.392857    Aircon
# 296    0.771349             0.0  1.000000  0.495933  0.410714    Aircon
# 297    0.759570             0.0  1.000000  0.513197  0.428571    Aircon
# 298    0.725265             0.0  0.953125  0.448705  0.363095    Aircon
# 299    0.616166             0.0  0.994792  0.573373  0.232143    Aircon

# %%
consumption_predict = nf.predict(futr_df=futr_df).reset_index()
consumption_predict.head()
# Out:
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
#   unique_id         ds       RNN       GRU      LSTM       TCN  DilatedRNN  \
# 0    Aircon 2023-10-23 -0.003765  0.001875  0.000757  0.001369    0.005308
# 1    Aircon 2023-10-24 -0.002244  0.003480 -0.000198  0.002409    0.005081
# 2    Aircon 2023-10-25 -0.000652  0.001929 -0.000283  0.001561    0.004017
# 3    Aircon 2023-10-26 -0.000010  0.002397  0.001231  0.002679    0.005051
# 4    Aircon 2023-10-27  0.004546  0.006976  0.004145  0.006659    0.009386
#
#         MLP     NHITS    NBEATS   NBEATSx
# 0  0.003426 -0.000102 -0.007408  0.029458
# 1 -0.001419 -0.002336  0.002019  0.004433
# 2  0.003254  0.001504 -0.007340 -0.017543
# 3  0.006323  0.003396  0.005736 -0.002234
# 4 -0.004586  0.003071  0.003898 -0.008494

# %%
consumption_predict.drop('unique_id', axis=1, inplace=True)

# %%
just_production = df[df['unique_id'] == 'Aircon']

# %%
consumption_predict_plot = long_form(consumption_predict)
consumption_predict_plot = pd.concat([consumption_predict_plot, just_production.tail(50)]
                                     , ignore_index=True)
consumption_predict_plot
# Out:
#             ds unique_id         y
# 0   2023-10-23       RNN -0.003765
# 1   2023-10-24       RNN -0.002244
# 2   2023-10-25       RNN -0.000652
# 3   2023-10-26       RNN -0.000010
# 4   2023-10-27       RNN  0.004546
# ..         ...       ...       ...
# 135 2023-10-28    Aircon  0.000327
# 136 2023-10-29    Aircon  0.000459
# 137 2023-10-30    Aircon  0.000367
# 138 2023-10-31    Aircon  0.001045
# 139 2023-11-01    Aircon  0.000589
#
# [140 rows x 3 columns]

# %%
altair_plot(consumption_predict_plot)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Performance

# %%
from datasetsforecast.losses import (mae, mape, mase, rmse, smape)

# %%
consumption_predict.info(), consumption_predict.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ds          10 non-null     datetime64[ns]
#  1   RNN         10 non-null     float64
#  2   GRU         10 non-null     float64
#  3   LSTM        10 non-null     float64
#  4   TCN         10 non-null     float64
#  5   DilatedRNN  10 non-null     float64
#  6   MLP         10 non-null     float64
#  7   NHITS       10 non-null     float64
#  8   NBEATS      10 non-null     float64
#  9   NBEATSx     10 non-null     float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 932.0 bytes
# (None,
#  Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#         'NBEATS', 'NBEATSx'],
#        dtype='object'))

# %%
def evaluate_performace(y_hist, y_true, y_pred):
    #y_true = y_true.merge(y_pred, how='left', on=['unique_id', 'ds'])
    evaluation = {}
    print(y_pred.columns)
    for i, model in enumerate(y_pred.columns):
        if i < 2: continue
        evaluation[model] = {}
        for metric in [mase, mae, mape, rmse, smape]:
            metric_name = metric.__name__
            if metric_name == 'mase':
                evaluation[model][metric_name] = metric(y_true['y'].values, 
                                                    y_pred[model].values, 
                                                    y_hist['y'].values, seasonality=12)
            else:
                evaluation[model][metric_name] = metric(y_true['y'].values, y_pred[model].values)
    return pd.DataFrame(evaluation)

# %%
score = evaluate_performace(train, test, consumption_predict)
score.style.background_gradient(cmap ='YlGn', axis = 1,low=0.5, high=0.6)
# Out:
# Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#        'NBEATS', 'NBEATSx'],
#       dtype='object')
# <style type="text/css">
# #T_61a60_row0_col0, #T_61a60_row1_col0, #T_61a60_row2_col1, #T_61a60_row3_col3, #T_61a60_row4_col1 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_61a60_row0_col1, #T_61a60_row1_col1 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_61a60_row0_col2, #T_61a60_row1_col2, #T_61a60_row3_col7 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# #T_61a60_row0_col3, #T_61a60_row1_col3 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_61a60_row0_col4, #T_61a60_row1_col4 {
#   background-color: #329850;
#   color: #f1f1f1;
# }
# #T_61a60_row0_col5, #T_61a60_row1_col5 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_61a60_row0_col6, #T_61a60_row1_col6 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_61a60_row0_col7, #T_61a60_row1_col7, #T_61a60_row2_col7, #T_61a60_row3_col6, #T_61a60_row4_col4, #T_61a60_row4_col7 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_61a60_row2_col0 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_61a60_row2_col2 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_61a60_row2_col3, #T_61a60_row3_col2 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_61a60_row2_col4 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_61a60_row2_col5 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_61a60_row2_col6 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_61a60_row3_col0 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_61a60_row3_col1 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_61a60_row3_col4 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_61a60_row3_col5 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_61a60_row4_col0 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_61a60_row4_col2 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_61a60_row4_col3 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_61a60_row4_col5 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_61a60_row4_col6 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61a60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61a60_level0_col0" class="col_heading level0 col0" >GRU</th>
#       <th id="T_61a60_level0_col1" class="col_heading level0 col1" >LSTM</th>
#       <th id="T_61a60_level0_col2" class="col_heading level0 col2" >TCN</th>
#       <th id="T_61a60_level0_col3" class="col_heading level0 col3" >DilatedRNN</th>
#       <th id="T_61a60_level0_col4" class="col_heading level0 col4" >MLP</th>
#       <th id="T_61a60_level0_col5" class="col_heading level0 col5" >NHITS</th>
#       <th id="T_61a60_level0_col6" class="col_heading level0 col6" >NBEATS</th>
#       <th id="T_61a60_level0_col7" class="col_heading level0 col7" >NBEATSx</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61a60_level0_row0" class="row_heading level0 row0" >mase</th>
#       <td id="T_61a60_row0_col0" class="data row0 col0" >0.371110</td>
#       <td id="T_61a60_row0_col1" class="data row0 col1" >0.373379</td>
#       <td id="T_61a60_row0_col2" class="data row0 col2" >0.376333</td>
#       <td id="T_61a60_row0_col3" class="data row0 col3" >0.386538</td>
#       <td id="T_61a60_row0_col4" class="data row0 col4" >0.426027</td>
#       <td id="T_61a60_row0_col5" class="data row0 col5" >0.392198</td>
#       <td id="T_61a60_row0_col6" class="data row0 col6" >0.419957</td>
#       <td id="T_61a60_row0_col7" class="data row0 col7" >0.429512</td>
#     </tr>
#     <tr>
#       <th id="T_61a60_level0_row1" class="row_heading level0 row1" >mae</th>
#       <td id="T_61a60_row1_col0" class="data row1 col0" >0.048412</td>
#       <td id="T_61a60_row1_col1" class="data row1 col1" >0.048708</td>
#       <td id="T_61a60_row1_col2" class="data row1 col2" >0.049094</td>
#       <td id="T_61a60_row1_col3" class="data row1 col3" >0.050425</td>
#       <td id="T_61a60_row1_col4" class="data row1 col4" >0.055577</td>
#       <td id="T_61a60_row1_col5" class="data row1 col5" >0.051163</td>
#       <td id="T_61a60_row1_col6" class="data row1 col6" >0.054785</td>
#       <td id="T_61a60_row1_col7" class="data row1 col7" >0.056031</td>
#     </tr>
#     <tr>
#       <th id="T_61a60_level0_row2" class="row_heading level0 row2" >mape</th>
#       <td id="T_61a60_row2_col0" class="data row2 col0" >259.057162</td>
#       <td id="T_61a60_row2_col1" class="data row2 col1" >160.017654</td>
#       <td id="T_61a60_row2_col2" class="data row2 col2" >375.530638</td>
#       <td id="T_61a60_row2_col3" class="data row2 col3" >807.648400</td>
#       <td id="T_61a60_row2_col4" class="data row2 col4" >1278.895162</td>
#       <td id="T_61a60_row2_col5" class="data row2 col5" >616.177544</td>
#       <td id="T_61a60_row2_col6" class="data row2 col6" >1099.112504</td>
#       <td id="T_61a60_row2_col7" class="data row2 col7" >2281.618162</td>
#     </tr>
#     <tr>
#       <th id="T_61a60_level0_row3" class="row_heading level0 row3" >rmse</th>
#       <td id="T_61a60_row3_col0" class="data row3 col0" >0.086880</td>
#       <td id="T_61a60_row3_col1" class="data row3 col1" >0.088143</td>
#       <td id="T_61a60_row3_col2" class="data row3 col2" >0.087256</td>
#       <td id="T_61a60_row3_col3" class="data row3 col3" >0.085695</td>
#       <td id="T_61a60_row3_col4" class="data row3 col4" >0.088678</td>
#       <td id="T_61a60_row3_col5" class="data row3 col5" >0.088601</td>
#       <td id="T_61a60_row3_col6" class="data row3 col6" >0.090735</td>
#       <td id="T_61a60_row3_col7" class="data row3 col7" >0.086129</td>
#     </tr>
#     <tr>
#       <th id="T_61a60_level0_row4" class="row_heading level0 row4" >smape</th>
#       <td id="T_61a60_row4_col0" class="data row4 col0" >138.050393</td>
#       <td id="T_61a60_row4_col1" class="data row4 col1" >137.216017</td>
#       <td id="T_61a60_row4_col2" class="data row4 col2" >143.938382</td>
#       <td id="T_61a60_row4_col3" class="data row4 col3" >171.561234</td>
#       <td id="T_61a60_row4_col4" class="data row4 col4" >187.530805</td>
#       <td id="T_61a60_row4_col5" class="data row4 col5" >164.534808</td>
#       <td id="T_61a60_row4_col6" class="data row4 col6" >173.732277</td>
#       <td id="T_61a60_row4_col7" class="data row4 col7" >187.285272</td>
#     </tr>
#   </tbody>
# </table>

# %%
score = data_scaler(score.T)
score.plot(kind='bar', legend=True)
# Out:
# <Axes: >

# %%
results = evaluate_performace(train, test, consumption_predict)
results.to_csv('Data/Neutral_results6.csv')
# Out:
# Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#        'NBEATS', 'NBEATSx'],
#       dtype='object')

# %% [markdown]
# ## Cross_Validate

# %%
cv_df = nf.cross_validation(train,
                            n_windows=3,
                            step_size= 1,
                           )
# Out:
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
cv_df.columns
# Out:
# Index(['unique_id', 'ds', 'cutoff', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN',
#        'MLP', 'NHITS', 'NBEATS', 'NBEATSx', 'y', 'Export', 'Fridge', 'Garage',
#        'Hotwater', 'HouseBoardOutside', 'HouseBoardOutsideR', 'HouseBoardR',
#        'Import', 'Lights', 'Net', 'OvenStove', 'Powerpoints', 'Production',
#        'temp_c', 'is_day', 'wind_kph', 'wind_degree', 'pressure_mb',
#        'precip_mm', 'humidity', 'cloud', 'feelslike_c', 'windchill_c',
#        'heatindex_c', 'dewpoint_c', 'chance_of_rain', 'vis_km', 'gust_kph',
#        'uv'],
#       dtype='object')

# %%
cv_df.drop('cutoff', axis=1, inplace=True)
cv_df.drop('unique_id', axis=1, inplace=True)

# %%
cv_df['RNN']
# Out:
# 0     0.003673
# 1     0.003411
# 2     0.005272
# 3     0.004834
# 4     0.003371
# 5     0.004693
# 6     0.002750
# 7     0.003084
# 8     0.003110
# 9     0.003422
# 10    0.003683
# 11    0.004200
# 12    0.004993
# 13    0.003823
# 14    0.003562
# 15    0.002538
# 16    0.003389
# 17    0.001889
# 18    0.003593
# 19    0.002887
# 20    0.003859
# 21    0.004063
# 22    0.004764
# 23    0.004584
# 24    0.002643
# 25    0.002991
# 26    0.002939
# 27    0.002597
# 28    0.003465
# 29    0.003382
# Name: RNN, dtype: float32

# %%
consumption_predict.columns
# Out:
# Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#        'NBEATS', 'NBEATSx'],
#       dtype='object')

# %%
cv_df_filter = cv_df[consumption_predict.columns]
cv_df_filter
# Out:
#            ds       RNN       GRU      LSTM       TCN  DilatedRNN       MLP  \
# 0  2023-10-11  0.003673  0.005021  0.004987  0.005792    0.005489 -0.009889
# 1  2023-10-12  0.003411  0.005343  0.005253  0.005539    0.006155 -0.005851
# 2  2023-10-13  0.005272  0.004845  0.005999  0.007143    0.004875 -0.002195
# 3  2023-10-14  0.004834  0.004222  0.005454  0.007220    0.005831 -0.001914
# 4  2023-10-15  0.003371  0.004710  0.005032  0.006623    0.005268 -0.005891
# 5  2023-10-16  0.004693  0.004753  0.004767  0.006278    0.005445 -0.007138
# 6  2023-10-17  0.002750  0.002801  0.001887  0.003215    0.004832 -0.002510
# 7  2023-10-18  0.003084  0.003364  0.003110  0.005126    0.006354 -0.000340
# 8  2023-10-19  0.003110  0.002219  0.003411  0.004707    0.005641  0.004607
# 9  2023-10-20  0.003422  0.002788  0.003836  0.005737    0.005702 -0.001130
# 10 2023-10-12  0.003683  0.005175  0.004413  0.005611    0.005654 -0.007089
# 11 2023-10-13  0.004200  0.006124  0.006182  0.007197    0.004898 -0.004902
# 12 2023-10-14  0.004993  0.005107  0.005692  0.007183    0.005525 -0.001707
# 13 2023-10-15  0.003823  0.003455  0.004988  0.006447    0.005087 -0.000212
# 14 2023-10-16  0.003562  0.004341  0.005024  0.006695    0.004611 -0.007060
# 15 2023-10-17  0.002538  0.002963  0.001651  0.003516    0.004259 -0.005497
# 16 2023-10-18  0.003389  0.003141  0.002055  0.004616    0.005372  0.000017
# 17 2023-10-19  0.001889  0.002799  0.002895  0.004982    0.006241  0.001313
# 18 2023-10-20  0.003593  0.002599  0.004550  0.005695    0.005590  0.005149
# 19 2023-10-21  0.002887  0.003031  0.003053  0.004711    0.005212  0.000061
# 20 2023-10-13  0.003859  0.005407  0.005920  0.006619    0.006034 -0.007852
# 21 2023-10-14  0.004063  0.006056  0.005797  0.007344    0.005953 -0.004207
# 22 2023-10-15  0.004764  0.004569  0.005187  0.006584    0.004831 -0.000522
# 23 2023-10-16  0.004584  0.003823  0.004438  0.006753    0.004477 -0.002999
# 24 2023-10-17  0.002643  0.002456  0.001815  0.003857    0.005319 -0.006987
# 25 2023-10-18  0.002991  0.003463  0.002342  0.004471    0.005252 -0.007555
# 26 2023-10-19  0.002939  0.002420  0.002808  0.004705    0.005759 -0.003243
# 27 2023-10-20  0.002597  0.003378  0.003937  0.006227    0.005866  0.000581
# 28 2023-10-21  0.003465  0.003007  0.003841  0.005584    0.005469  0.004090
# 29 2023-10-22  0.003382  0.002835  0.003759  0.005523    0.006076  0.001502
#
#        NHITS    NBEATS   NBEATSx
# 0  -0.003473 -0.001256 -0.030136
# 1  -0.002714  0.004471 -0.001906
# 2  -0.004884 -0.004693 -0.008124
# 3  -0.004632  0.003145  0.017054
# 4  -0.005599  0.005866 -0.004327
# 5   0.014494 -0.010272 -0.012851
# 6   0.015675  0.006893 -0.014723
# 7  -0.000863  0.007038  0.006363
# 8  -0.002232 -0.005905 -0.017330
# 9  -0.005217 -0.000549 -0.017569
# 10 -0.003497 -0.001838 -0.029171
# 11 -0.003242  0.003925 -0.004157
# 12 -0.005932 -0.005245 -0.006840
# 13 -0.004289  0.002667  0.018079
# 14 -0.006028  0.005395 -0.003859
# 15  0.013891 -0.010744 -0.013867
# 16  0.016669  0.006431 -0.017220
# 17  0.000602  0.006591  0.009745
# 18 -0.001900 -0.006328 -0.020834
# 19 -0.004911 -0.000964 -0.015837
# 20 -0.003390 -0.002004 -0.033442
# 21 -0.003498  0.003762 -0.002752
# 22 -0.005164 -0.005370 -0.004247
# 23 -0.003351  0.002537  0.017125
# 24 -0.004216  0.005273 -0.005012
# 25  0.015235 -0.010860 -0.016209
# 26  0.017825  0.006352 -0.015042
# 27  0.001925  0.006536  0.007198
# 28 -0.001287 -0.006406 -0.018812
# 29 -0.003799 -0.001092 -0.019789

# %%
cv_df_plot = long_form(cv_df_filter)

# %%
cv_df_plot
# Out:
#             ds unique_id         y
# 0   2023-10-11       RNN  0.003673
# 1   2023-10-12       RNN  0.003411
# 2   2023-10-13       RNN  0.005272
# 3   2023-10-14       RNN  0.004834
# 4   2023-10-15       RNN  0.003371
# ..         ...       ...       ...
# 265 2023-10-18   NBEATSx -0.016209
# 266 2023-10-19   NBEATSx -0.015042
# 267 2023-10-20   NBEATSx  0.007198
# 268 2023-10-21   NBEATSx -0.018812
# 269 2023-10-22   NBEATSx -0.019789
#
# [270 rows x 3 columns]

# %%
altair_plot(cv_df_plot)
# Out:
# alt.LayerChart(...)
