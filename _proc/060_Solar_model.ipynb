# %% [raw]
# ---
# description: 'Assumption: consumption = func(individual components, future weather,
#   future humidity)'
# output-file: solar_model.html
# skip_exec: true
# skip_showdoc: true
# title: Solar Model
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Get Data

# %%
#|eval: false
result = query_api.query_data_frame(org=org, query=query)
result.columns
# Out:
# Index(['result', 'table', '_start', '_stop', '_time', '_value', '_field',
#        '_measurement', 'device', 'sensor', 'units'],
#       dtype='object')

# %%
#|eval: false
result.shape
# Out:
# (4182, 11)

# %% [markdown]
#  result.to_csv(f'./Data/energy_info.csv', index=False) #save the data as a csv

# %%
result.drop(['result', 'table', '_field', '_start', '_stop', '_measurement', 'units', 'device'], axis=1, inplace=True)

# %%
#|eval: false
result.head()
# Out:
#                       _time      _value  sensor
# 0 2023-03-02 00:00:00+00:00   12.888000  Aircon
# 1 2023-03-03 00:00:00+00:00  121.541007  Aircon
# 2 2023-03-04 00:00:00+00:00  222.993806  Aircon
# 3 2023-03-05 00:00:00+00:00  118.435757  Aircon
# 4 2023-03-06 00:00:00+00:00  238.721389  Aircon

# %%
#|eval: false
result.columns
# Out:
# Index(['_time', '_value', 'sensor'], dtype='object')

# %% [markdown]
# ## Energy in Wide Form

# %%
#|eval: false
wide_df = result.pivot(index='_time', columns='sensor', values='_value')
# Reset the index to make 'id' a regular column
wide_df.reset_index(inplace=True)

wide_df.columns
# Out:
# Index(['_time', 'Aircon', 'Consumption', 'ConsumptionNet', 'Export', 'Fridge',
#        'Garage', 'Hotwater', 'HouseBoardOutside', 'HouseBoardOutsideR',
#        'HouseBoardR', 'Import', 'Lights', 'Net', 'OvenStove', 'Powerpoints',
#        'Production', 'Unmonitored'],
#       dtype='object', name='sensor')

# %%
wide_df['_time'] = pd.to_datetime(wide_df['_time']).dt.tz_localize(None)
wide_df.drop(['Unmonitored', 'Consumption', 'ConsumptionNet', 'Export'], axis = 1, inplace=True)
wide_df.rename(columns={'_time':'ds'}, inplace=True)
# Delete the last row
wide_df = wide_df.drop(wide_df.index[-1])

# %%
wide_df_new = pd.DataFrame()
for column in wide_df.columns:
    wide_df_new[f'{column}'] = wide_df[f'{column}'].interpolate()

wide_df = pd.DataFrame(wide_df_new)
wide_df.columns
# Out:
# Index(['ds', 'Aircon', 'Fridge', 'Garage', 'Hotwater', 'HouseBoardOutside',
#        'HouseBoardOutsideR', 'HouseBoardR', 'Import', 'Lights', 'Net',
#        'OvenStove', 'Powerpoints', 'Production'],
#       dtype='object')

# %%
wide_df.tail()
# Out:
#             ds    Aircon     Fridge     Garage  Hotwater  HouseBoardOutside  \
# 240 2023-10-28  8.578005  25.492343  24.017087  0.530865         999.775552
# 241 2023-10-29  8.661682  19.634587   2.731102  0.192283         530.312474
# 242 2023-10-30  8.603354  27.081000   0.983716  0.183639         788.486015
# 243 2023-10-31  9.032917  35.649472  11.163953  0.269313         901.165305
# 244 2023-11-01  8.743938  30.389375   3.655479  0.189410         623.050504
#
#      HouseBoardOutsideR  HouseBoardR     Import     Lights         Net  \
# 240          333.258545   366.408449  71.876417  80.009421 -108.365830
# 241          176.770805   201.397413   1.974071  60.108551 -804.636021
# 242          262.828480   290.616882   3.378339  66.827993 -754.223132
# 243          300.388379   319.795146   5.027126  67.972347 -798.814844
# 244          207.683462   245.486118   2.309883  50.624125 -896.285107
#
#      OvenStove  Powerpoints   Production
# 240  66.086281   176.392548   491.748285
# 241   1.253300   103.451046  1017.375874
# 242   1.356785   178.170521  1052.272015
# 243  30.217549   166.649785  1142.661342
# 244   0.213375   145.941312  1134.978184

# %%
def data_scaler(df):
    import pandas as pd
    from sklearn.preprocessing import MinMaxScaler

    numeric_columns = df.select_dtypes(include=['number']).columns
        
    # Scale numeric columns
    df[numeric_columns] = MinMaxScaler().fit_transform(df[numeric_columns])

    return df

# %%
def long_form(df_plot):
    return df_plot.melt('ds', var_name='unique_id', value_name='y')

def altair_plot(df_plot): 
    import altair as alt
    highlight = alt.selection_point(on='mouseover', fields=['unique_id'], bind='legend', nearest=True)

    base = alt.Chart(df_plot).encode(
        x='ds:T',
        y='y:Q',
        color='unique_id:N'
    )

    points = base.mark_circle().encode(
        opacity=alt.value(0)
    ).add_params(
        highlight
    ).properties(
        width=1000
    )

    lines = base.mark_line().encode(
        size=alt.condition(~highlight, alt.value(1), alt.value(3))
    )

    return points + lines

# %%
wide_df = data_scaler(wide_df)
wide_df.tail()
# Out:
#             ds    Aircon    Fridge    Garage  Hotwater  HouseBoardOutside  \
# 240 2023-10-28  0.000327  0.054518  0.475787  0.000988           0.441317
# 241 2023-10-29  0.000459  0.008991  0.049113  0.000167           0.155476
# 242 2023-10-30  0.000367  0.066865  0.014087  0.000146           0.312670
# 243 2023-10-31  0.001045  0.133461  0.218148  0.000354           0.381277
# 244 2023-11-01  0.000589  0.092579  0.067642  0.000160           0.211942
#
#      HouseBoardOutsideR  HouseBoardR    Import    Lights       Net  OvenStove  \
# 240            0.270647     0.263152  0.098826  0.397064  0.702175   0.217335
# 241            0.095349     0.096613  0.001842  0.287229  0.452268   0.003559
# 242            0.191751     0.186659  0.003790  0.324314  0.470363   0.003900
# 243            0.233826     0.216107  0.006078  0.330630  0.454358   0.099064
# 244            0.129978     0.141110  0.002308  0.234883  0.419373   0.000130
#
#      Powerpoints  Production
# 240     0.451213    0.164710
# 241     0.195780    0.385757
# 242     0.457440    0.400433
# 243     0.417095    0.438445
# 244     0.344577    0.435214

# %%
df = long_form(wide_df)
wide_df.rename(columns={'Production': 'y'}, inplace=True)
wide_df['unique_id'] = 'Production'
df.head()
# Out:
#           ds unique_id         y
# 0 2023-03-02    Aircon  0.007134
# 1 2023-03-03    Aircon  0.178748
# 2 2023-03-04    Aircon  0.338990
# 3 2023-03-05    Aircon  0.173844
# 4 2023-03-06    Aircon  0.363831

# %% [markdown]
# ## Weather data

# %%
import pandas as pd
path = 'Data'
name = 'weather'

weather_df = pd.read_csv(f'{path}/{name}.csv')
weather_df.head()
# Out:
#                  ds  temp_c  is_day  wind_kph  wind_degree  pressure_mb  \
# 0  2023-01-01 00:00    21.6       0      12.6          126       1013.0
# 1  2023-01-01 01:00    21.3       0      11.9          133       1013.0
# 2  2023-01-01 02:00    21.1       0      11.2          140       1012.0
# 3  2023-01-01 03:00    20.8       0      10.4          147       1012.0
# 4  2023-01-01 04:00    21.0       0      10.6          144       1012.0
#
#    precip_mm  humidity  cloud  feelslike_c  windchill_c  heatindex_c  \
# 0        0.0        84     73         21.6         21.6         24.4
# 1        0.0        85     77         21.3         21.3         24.3
# 2        0.0        86     80         21.1         21.1         24.2
# 3        0.0        88     84         20.8         20.8         20.8
# 4        0.0        86     84         21.0         21.0         21.0
#
#    dewpoint_c  chance_of_rain  vis_km  gust_kph   uv
# 0        18.7               0    10.0      19.8  1.0
# 1        18.7               0    10.0      18.7  1.0
# 2        18.7               0    10.0      17.6  1.0
# 3        18.7               0    10.0      16.6  1.0
# 4        18.6               0    10.0      16.3  1.0

# %%
weather_df = data_scaler(weather_df)

# %%
def data_day_avg(weather_df):
    from tqdm.notebook import tqdm
    avg_df = pd.DataFrame()
    dates = pd.to_datetime(weather_df['ds']).dt.date.unique()
    
    for date in tqdm(dates):
        filtered_df = weather_df[pd.to_datetime(weather_df['ds']).dt.date == date]
        ds = filtered_df.pop('ds')

        filtered_df = pd.DataFrame(filtered_df.mean()).T
        filtered_df

        filtered_df.insert(0, 'ds', date)

        avg_df = pd.concat([avg_df, filtered_df], ignore_index=True)
    
    return avg_df

# %%
weather_avg_df = data_day_avg(weather_df)
# Out:
#   0%|          | 0/344 [00:00<?, ?it/s]

# %%
weather_avg_df['ds'] = pd.to_datetime(weather_avg_df['ds'])

# %%
weather_avg_df
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 0   2023-01-01  0.566503  0.583333  0.459098     0.345636     0.428728
# 1   2023-01-02  0.554902  0.583333  0.451453     0.396936     0.359649
# 2   2023-01-03  0.582516  0.583333  0.263889     0.415506     0.258772
# 3   2023-01-04  0.650490  0.583333  0.313073     0.382660     0.163377
# 4   2023-01-05  0.654575  0.583333  0.257518     0.506267     0.166667
# ..         ...       ...       ...       ...          ...          ...
# 339 2023-12-06  0.580556  0.583333  0.254077     0.264740     0.558114
# 340 2023-12-07  0.605065  0.583333  0.266565     0.202066     0.565789
# 341 2023-12-08  0.618954  0.583333  0.349261     0.251625     0.575658
# 342 2023-12-09  0.612582  0.583333  0.362768     0.190460     0.544956
# 343 2023-12-10  0.630556  0.583333  0.513507     0.233751     0.530702
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 0     0.000895  0.670886  0.583750     0.516791     0.595085     0.512881
# 1     0.001253  0.602848  0.409167     0.499005     0.584249     0.486067
# 2     0.000000  0.584916  0.287917     0.525746     0.610043     0.502366
# 3     0.000895  0.687764  0.196250     0.608582     0.673535     0.609621
# 4     0.026859  0.735232  0.700417     0.629726     0.677350     0.608701
# ..         ...       ...       ...          ...          ...          ...
# 339   0.000000  0.608650  0.174583     0.519527     0.608364     0.515116
# 340   0.000000  0.582806  0.050000     0.543532     0.631258     0.533386
# 341   0.000018  0.626582  0.342083     0.561816     0.644078     0.555205
# 342   0.000107  0.577532  0.497500     0.564179     0.638584     0.539432
# 343   0.000233  0.515295  0.537500     0.571269     0.655067     0.546924
#
#      dewpoint_c  chance_of_rain    vis_km  gust_kph        uv
# 0      0.778121             0.0  1.000000  0.434678  0.422619
# 1      0.725707             0.0  1.000000  0.434844  0.428571
# 2      0.738663             0.0  1.000000  0.283533  0.452381
# 3      0.866902             0.0  0.994792  0.305777  0.500000
# 4      0.911808             0.0  0.989583  0.288098  0.416667
# ..          ...             ...       ...       ...       ...
# 339    0.745878             0.0  1.000000  0.214558  0.470238
# 340    0.748233             0.0  1.000000  0.222693  0.476190
# 341    0.795200             0.0  1.000000  0.285940  0.476190
# 342    0.757509             0.0  1.000000  0.308267  0.428571
# 343    0.730271             0.0  1.000000  0.426627  0.452381
#
# [344 rows x 17 columns]

# %%
#|eval: false
(
    wide_df[['y']].plot(title='Production')
)
# Out:
# <Axes: title={'center': 'Production'}>

# %%
#|eval: false
from statsforecast import StatsForecast

# %%
#|eval: false
from pylab import rcParams
rcParams['figure.figsize'] = (15,4)
StatsForecast.plot(df, engine='plotly')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
wide_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ds                  245 non-null    datetime64[ns]
#  1   Aircon              245 non-null    float64
#  2   Fridge              245 non-null    float64
#  3   Garage              245 non-null    float64
#  4   Hotwater            245 non-null    float64
#  5   HouseBoardOutside   161 non-null    float64
#  6   HouseBoardOutsideR  245 non-null    float64
#  7   HouseBoardR         245 non-null    float64
#  8   Import              245 non-null    float64
#  9   Lights              245 non-null    float64
#  10  Net                 245 non-null    float64
#  11  OvenStove           245 non-null    float64
#  12  Powerpoints         245 non-null    float64
#  13  y                   245 non-null    float64
#  14  unique_id           245 non-null    object
# dtypes: datetime64[ns](1), float64(13), object(1)
# memory usage: 28.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3185 entries, 0 to 3184
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ds         3185 non-null   datetime64[ns]
#  1   unique_id  3185 non-null   object
#  2   y          3101 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 74.8+ KB

# %%
weather_avg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ds              344 non-null    datetime64[ns]
#  1   temp_c          344 non-null    float64
#  2   is_day          344 non-null    float64
#  3   wind_kph        344 non-null    float64
#  4   wind_degree     344 non-null    float64
#  5   pressure_mb     344 non-null    float64
#  6   precip_mm       344 non-null    float64
#  7   humidity        344 non-null    float64
#  8   cloud           344 non-null    float64
#  9   feelslike_c     344 non-null    float64
#  10  windchill_c     344 non-null    float64
#  11  heatindex_c     344 non-null    float64
#  12  dewpoint_c      344 non-null    float64
#  13  chance_of_rain  344 non-null    float64
#  14  vis_km          344 non-null    float64
#  15  gust_kph        344 non-null    float64
#  16  uv              344 non-null    float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 45.8 KB

# %%
date_range_start, date_range_end  = wide_df['ds'].min(), wide_df['ds'].max()
# Filter rows between the start and end dates
weather_avg_filtered_df = weather_avg_df[(weather_avg_df['ds'] >= date_range_start) & (weather_avg_df['ds'] <= date_range_end)]
weather_avg_filtered_df
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 60  2023-03-02  0.644444  0.541667  0.294980     0.153784     0.344298
# 61  2023-03-03  0.603268  0.541667  0.483563     0.386142     0.403509
# 62  2023-03-04  0.561765  0.541667  0.574669     0.433612     0.425439
# 63  2023-03-05  0.598039  0.541667  0.372324     0.350627     0.427632
# 64  2023-03-06  0.629575  0.541667  0.313073     0.290854     0.417763
# ..         ...       ...       ...       ...          ...          ...
# 300 2023-10-28  0.379575  0.541667  0.700051     0.446611     0.708333
# 301 2023-10-29  0.382516  0.541667  0.383028     0.320682     0.656798
# 302 2023-10-30  0.441340  0.583333  0.396152     0.435237     0.562500
# 303 2023-10-31  0.550163  0.583333  0.489424     0.549559     0.442982
# 304 2023-11-01  0.510784  0.583333  0.561672     0.445218     0.505482
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 60    0.001056  0.675633  0.345417     0.609826     0.667888     0.594374
# 61    0.002131  0.682489  0.579167     0.572388     0.629426     0.548107
# 62    0.000161  0.604430  0.364583     0.509204     0.590659     0.491982
# 63    0.000358  0.603903  0.401250     0.542537     0.624542     0.531677
# 64    0.000358  0.608650  0.157500     0.568284     0.653999     0.557965
# ..         ...       ...       ...          ...          ...          ...
# 300   0.000233  0.500000  0.389167     0.351741     0.414835     0.327681
# 301   0.000125  0.524789  0.433750     0.347637     0.423230     0.329390
# 302   0.000000  0.583861  0.181250     0.403483     0.478327     0.373686
# 303   0.000000  0.570675  0.025417     0.492537     0.579976     0.467140
# 304   0.000340  0.599156  0.480000     0.458209     0.543040     0.435594
#
#      dewpoint_c  chance_of_rain  vis_km  gust_kph        uv
# 60     0.845112             0.0     1.0  0.250332  0.470238
# 61     0.821555             0.0     1.0  0.432022  0.380952
# 62     0.734982             0.0     1.0  0.485309  0.422619
# 63     0.761042             0.0     1.0  0.319804  0.428571
# 64     0.785925             0.0     1.0  0.263363  0.476190
# ..          ...             ...     ...       ...       ...
# 300    0.497939             0.0     1.0  0.588811  0.345238
# 301    0.525324             0.0     1.0  0.328934  0.345238
# 302    0.611307             0.0     1.0  0.340139  0.416667
# 303    0.687132             0.0     1.0  0.470286  0.464286
# 304    0.685218             0.0     1.0  0.467795  0.404762
#
# [245 rows x 17 columns]

# %%
altair_plot(df)
# Out:
# alt.LayerChart(...)

# %%
weather_avg_df_plot = long_form(weather_avg_filtered_df)
altair_plot(weather_avg_df_plot)
# Out:
# alt.LayerChart(...)

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
wide_df["y"]
# Out:
# 0      0.128585
# 1      0.168068
# 2      0.283984
# 3      0.285599
# 4      0.368173
#          ...
# 240    0.164710
# 241    0.385757
# 242    0.400433
# 243    0.438445
# 244    0.435214
# Name: y, Length: 245, dtype: float64

# %%
def augmented_dickey_fuller_test(series , column_name):
    from statsmodels.tsa.stattools import adfuller
    print (f'Dickey-Fuller test results for columns: {column_name}')
    dftest = adfuller(series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','No Lags Used','Number of observations used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    if dftest[1] <= 0.05:
        print("Conclusion:====>")
        print("Reject the null hypothesis")
        print("The data is stationary")
    else:
        print("Conclusion:====>")
        print("The null hypothesis cannot be rejected")
        print("The data is not stationary")

# %%
augmented_dickey_fuller_test(wide_df["y"],'Ads')
# Out:
# Dickey-Fuller test results for columns: Ads
# Test Statistic                  -4.863065
# p-value                          0.000041
# No Lags Used                     2.000000
# Number of observations used    242.000000
# Critical Value (1%)             -3.457664
# Critical Value (5%)             -2.873559
# Critical Value (10%)            -2.573175
# dtype: float64
# Conclusion:====>
# Reject the null hypothesis
# The data is stationary

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)

plot_acf(wide_df["y"],  lags=28, ax=axs[0],color="fuchsia")
axs[0].set_title("Autocorrelation");

plot_pacf(wide_df["y"],  lags=28, ax=axs[1],color="lime")
axs[1].set_title('Partial Autocorrelation')

plt.show();

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)

plot_acf(wide_df["y"],  lags=14, ax=axs[0],color="fuchsia")
axs[0].set_title("Autocorrelation");

plot_pacf(wide_df["y"],  lags=14, ax=axs[1],color="lime")
axs[1].set_title('Partial Autocorrelation')

plt.show();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose 
a = seasonal_decompose(wide_df["y"], model = "additive", period=28)
a.plot();

# %% [markdown]
# ## Designing Models

# %%
weather_avg_filtered_df.head()
# Out:
#            ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 60 2023-03-02  0.644444  0.541667  0.294980     0.153784     0.344298
# 61 2023-03-03  0.603268  0.541667  0.483563     0.386142     0.403509
# 62 2023-03-04  0.561765  0.541667  0.574669     0.433612     0.425439
# 63 2023-03-05  0.598039  0.541667  0.372324     0.350627     0.427632
# 64 2023-03-06  0.629575  0.541667  0.313073     0.290854     0.417763
#
#     precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 60   0.001056  0.675633  0.345417     0.609826     0.667888     0.594374
# 61   0.002131  0.682489  0.579167     0.572388     0.629426     0.548107
# 62   0.000161  0.604430  0.364583     0.509204     0.590659     0.491982
# 63   0.000358  0.603903  0.401250     0.542537     0.624542     0.531677
# 64   0.000358  0.608650  0.157500     0.568284     0.653999     0.557965
#
#     dewpoint_c  chance_of_rain  vis_km  gust_kph        uv
# 60    0.845112             0.0     1.0  0.250332  0.470238
# 61    0.821555             0.0     1.0  0.432022  0.380952
# 62    0.734982             0.0     1.0  0.485309  0.422619
# 63    0.761042             0.0     1.0  0.319804  0.428571
# 64    0.785925             0.0     1.0  0.263363  0.476190

# %%
wide_df = pd.merge(wide_df, weather_avg_filtered_df, on='ds', how='outer')

# %%
wide_df.head()
# Out:
#           ds    Aircon    Fridge    Garage  Hotwater  HouseBoardOutside  \
# 0 2023-03-02  0.007134  0.814609  0.003794  0.000287                NaN
# 1 2023-03-03  0.178748  0.669709  0.015031  0.000143                NaN
# 2 2023-03-04  0.338990  0.686509  0.059559  0.000460                NaN
# 3 2023-03-05  0.173844  0.701288  0.009916  0.000256                NaN
# 4 2023-03-06  0.363831  0.773714  0.008798  0.002112                NaN
#
#    HouseBoardOutsideR  HouseBoardR    Import    Lights  ...  humidity  \
# 0            0.356702     0.364385  0.085067  1.000000  ...  0.675633
# 1            0.292065     0.295309  0.296304  0.219103  ...  0.682489
# 2            0.496691     0.501420  0.551547  0.449558  ...  0.604430
# 3            0.419958     0.422212  0.467784  0.642563  ...  0.603903
# 4            0.562640     0.561444  0.600856  0.401555  ...  0.608650
#
#       cloud  feelslike_c  windchill_c heatindex_c  dewpoint_c  chance_of_rain  \
# 0  0.345417     0.609826     0.667888    0.594374    0.845112             0.0
# 1  0.579167     0.572388     0.629426    0.548107    0.821555             0.0
# 2  0.364583     0.509204     0.590659    0.491982    0.734982             0.0
# 3  0.401250     0.542537     0.624542    0.531677    0.761042             0.0
# 4  0.157500     0.568284     0.653999    0.557965    0.785925             0.0
#
#    vis_km  gust_kph        uv
# 0     1.0  0.250332  0.470238
# 1     1.0  0.432022  0.380952
# 2     1.0  0.485309  0.422619
# 3     1.0  0.319804  0.428571
# 4     1.0  0.263363  0.476190
#
# [5 rows x 31 columns]

# %%
horizon = 10

train_size = len(wide_df) - horizon
train, test = wide_df[:train_size], wide_df[train_size:]


wide_df.shape, train.shape, test.shape
# Out:
# ((245, 31), (235, 31), (10, 31))

# %%
futr_df=weather_avg_filtered_df[train_size:]
futr_df['unique_id'] = 'Production'

# %%
futr_df.head()
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 295 2023-10-23  0.560784  0.500000  0.579256     0.550836     0.439693
# 296 2023-10-24  0.550490  0.541667  0.571738     0.437210     0.500000
# 297 2023-10-25  0.558660  0.541667  0.585117     0.546657     0.482456
# 298 2023-10-26  0.495261  0.541667  0.518349     0.551996     0.493421
# 299 2023-10-27  0.309314  0.541667  0.621814     0.516481     0.633772
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 295   0.000000  0.614979  0.075000     0.509328     0.589896     0.485279
# 296   0.000430  0.684599  0.150833     0.503483     0.580128     0.486593
# 297   0.000000  0.656646  0.073750     0.511070     0.588217     0.487119
# 298   0.005766  0.684072  0.593333     0.449627     0.528541     0.422581
# 299   0.008792  0.767932  0.862500     0.289552     0.355311     0.249211
#
#      dewpoint_c  chance_of_rain    vis_km  gust_kph        uv   unique_id
# 295    0.734246             0.0  1.000000  0.512699  0.392857  Production
# 296    0.771349             0.0  1.000000  0.495933  0.410714  Production
# 297    0.759570             0.0  1.000000  0.513197  0.428571  Production
# 298    0.725265             0.0  0.953125  0.448705  0.363095  Production
# 299    0.616166             0.0  0.994792  0.573373  0.232143  Production

# %%
from neuralforecast import models
models.__all__
# Out:
# ['RNN',
#  'GRU',
#  'LSTM',
#  'TCN',
#  'DeepAR',
#  'DilatedRNN',
#  'MLP',
#  'NHITS',
#  'NBEATS',
#  'NBEATSx',
#  'TFT',
#  'VanillaTransformer',
#  'Informer',
#  'Autoformer',
#  'PatchTST',
#  'FEDformer',
#  'StemGNN',
#  'HINT',
#  'TimesNet']

# %%
from ray import tune

from neuralforecast.core import NeuralForecast
from neuralforecast.auto import AutoMLP
from neuralforecast.models import *

# %%
model_list = [RNN,
 GRU,
 LSTM,
 TCN,
 #DeepAR,  # not good
 DilatedRNN,
 MLP,
 NHITS,
 NBEATS,
 NBEATSx,
 #TFT, # too much GPU
 #VanillaTransformer, # not good
 #Informer,
 #Autoformer,
 #PatchTST, # too much GPU
 #FEDformer, #taken too long
 #StemGNN, #need n_series
 #HINT, #need n_series
 #TimesNet # takes too long
             ]

# %%
wide_df.columns
# Out:
# Index(['ds', 'Aircon', 'Fridge', 'Garage', 'Hotwater', 'HouseBoardOutside',
#        'HouseBoardOutsideR', 'HouseBoardR', 'Import', 'Lights', 'Net',
#        'OvenStove', 'Powerpoints', 'y', 'unique_id', 'temp_c', 'is_day',
#        'wind_kph', 'wind_degree', 'pressure_mb', 'precip_mm', 'humidity',
#        'cloud', 'feelslike_c', 'windchill_c', 'heatindex_c', 'dewpoint_c',
#        'chance_of_rain', 'vis_km', 'gust_kph', 'uv'],
#       dtype='object')

# %%
models = [model(input_size=2 * horizon,
                h=horizon,
                max_steps=2000,
                hist_exog_list =['Aircon', 'Fridge', 'Garage',
                                 'Hotwater', 'HouseBoardR', 'Lights', 'Net',
                                 'OvenStove','Powerpoints'
                                ],
                futr_exog_list = ['temp_c', 'is_day', 'wind_kph', 'wind_degree',
                    'pressure_mb', 'precip_mm', 'humidity', 'cloud', 'feelslike_c',
                    'windchill_c', 'heatindex_c', 'dewpoint_c', 'chance_of_rain',
                    'vis_km', 'gust_kph', 'uv']
               ) for model in model_list]
models
# Out:
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# Global seed set to 1
# [RNN, GRU, LSTM, TCN, DilatedRNN, MLP, NHITS, NBEATS, NBEATSx]

# %%
nf = NeuralForecast(
    models=models, 
    freq='D')

# %%
train.columns
# Out:
# Index(['ds', 'Aircon', 'Fridge', 'Garage', 'Hotwater', 'HouseBoardOutside',
#        'HouseBoardOutsideR', 'HouseBoardR', 'Import', 'Lights', 'Net',
#        'OvenStove', 'Powerpoints', 'y', 'unique_id', 'temp_c', 'is_day',
#        'wind_kph', 'wind_degree', 'pressure_mb', 'precip_mm', 'humidity',
#        'cloud', 'feelslike_c', 'windchill_c', 'heatindex_c', 'dewpoint_c',
#        'chance_of_rain', 'vis_km', 'gust_kph', 'uv'],
#       dtype='object')

# %%
nf.fit(df=train)
# Out:
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
futr_df.head()
# Out:
#             ds    temp_c    is_day  wind_kph  wind_degree  pressure_mb  \
# 295 2023-10-23  0.560784  0.500000  0.579256     0.550836     0.439693
# 296 2023-10-24  0.550490  0.541667  0.571738     0.437210     0.500000
# 297 2023-10-25  0.558660  0.541667  0.585117     0.546657     0.482456
# 298 2023-10-26  0.495261  0.541667  0.518349     0.551996     0.493421
# 299 2023-10-27  0.309314  0.541667  0.621814     0.516481     0.633772
#
#      precip_mm  humidity     cloud  feelslike_c  windchill_c  heatindex_c  \
# 295   0.000000  0.614979  0.075000     0.509328     0.589896     0.485279
# 296   0.000430  0.684599  0.150833     0.503483     0.580128     0.486593
# 297   0.000000  0.656646  0.073750     0.511070     0.588217     0.487119
# 298   0.005766  0.684072  0.593333     0.449627     0.528541     0.422581
# 299   0.008792  0.767932  0.862500     0.289552     0.355311     0.249211
#
#      dewpoint_c  chance_of_rain    vis_km  gust_kph        uv   unique_id
# 295    0.734246             0.0  1.000000  0.512699  0.392857  Production
# 296    0.771349             0.0  1.000000  0.495933  0.410714  Production
# 297    0.759570             0.0  1.000000  0.513197  0.428571  Production
# 298    0.725265             0.0  0.953125  0.448705  0.363095  Production
# 299    0.616166             0.0  0.994792  0.573373  0.232143  Production

# %%
consumption_predict = nf.predict(futr_df=futr_df).reset_index()
consumption_predict.head()
# Out:
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
#     unique_id         ds       RNN       GRU      LSTM       TCN  DilatedRNN  \
# 0  Production 2023-10-23  0.507700  0.449085  0.476290  0.490807    0.548747
# 1  Production 2023-10-24  0.525197  0.460444  0.494279  0.507169    0.497478
# 2  Production 2023-10-25  0.453300  0.369578  0.385844  0.400484    0.412231
# 3  Production 2023-10-26  0.366417  0.374538  0.348836  0.326042    0.442334
# 4  Production 2023-10-27  0.174317  0.246273  0.306424  0.160848    0.238782
#
#         MLP     NHITS    NBEATS   NBEATSx
# 0  0.382190  0.446692  0.384382  0.424434
# 1  0.431177  0.445254  0.338512  0.455130
# 2  0.411991  0.466954  0.277904  0.433808
# 3  0.305548  0.374557  0.262405  0.404792
# 4  0.205710  0.382070  0.221150  0.392989

# %%
consumption_predict.drop('unique_id', axis=1, inplace=True)

# %%
just_production = df[df['unique_id'] == 'Production']

# %%
consumption_predict_plot = long_form(consumption_predict)
consumption_predict_plot = pd.concat([consumption_predict_plot, just_production.tail(50)]
                                     , ignore_index=True)
consumption_predict_plot
# Out:
#             ds   unique_id         y
# 0   2023-10-23         RNN  0.507700
# 1   2023-10-24         RNN  0.525197
# 2   2023-10-25         RNN  0.453300
# 3   2023-10-26         RNN  0.366417
# 4   2023-10-27         RNN  0.174317
# ..         ...         ...       ...
# 135 2023-10-28  Production  0.164710
# 136 2023-10-29  Production  0.385757
# 137 2023-10-30  Production  0.400433
# 138 2023-10-31  Production  0.438445
# 139 2023-11-01  Production  0.435214
#
# [140 rows x 3 columns]

# %%
plot_predict = consumption_predict.copy()
plot_predict.pop('ds')
# Out:
# 0   2023-10-23
# 1   2023-10-24
# 2   2023-10-25
# 3   2023-10-26
# 4   2023-10-27
# 5   2023-10-28
# 6   2023-10-29
# 7   2023-10-30
# 8   2023-10-31
# 9   2023-11-01
# Name: ds, dtype: datetime64[ns]

# %%
plot_predict.plot(kind='line', legend=True)
# Out:
# <Axes: >

# %%
altair_plot(consumption_predict_plot)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Performance

# %%
from datasetsforecast.losses import (mae, mape, mase, rmse, smape)

# %%
consumption_predict.info(), consumption_predict.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ds          10 non-null     datetime64[ns]
#  1   RNN         10 non-null     float64
#  2   GRU         10 non-null     float64
#  3   LSTM        10 non-null     float64
#  4   TCN         10 non-null     float64
#  5   DilatedRNN  10 non-null     float64
#  6   MLP         10 non-null     float64
#  7   NHITS       10 non-null     float64
#  8   NBEATS      10 non-null     float64
#  9   NBEATSx     10 non-null     float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 932.0 bytes
# (None,
#  Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#         'NBEATS', 'NBEATSx'],
#        dtype='object'))

# %%
def evaluate_performace(y_hist, y_true, y_pred):
    #y_true = y_true.merge(y_pred, how='left', on=['unique_id', 'ds'])
    evaluation = {}
    print(y_pred.columns)
    for i, model in enumerate(y_pred.columns):
        if i < 2: continue
        evaluation[model] = {}
        for metric in [mase, mae, mape, rmse, smape]:
            metric_name = metric.__name__
            if metric_name == 'mase':
                evaluation[model][metric_name] = metric(y_true['y'].values, 
                                                    y_pred[model].values, 
                                                    y_hist['y'].values, seasonality=12)
            else:
                evaluation[model][metric_name] = metric(y_true['y'].values, y_pred[model].values)
    return pd.DataFrame(evaluation)

# %%
score = evaluate_performace(train, test, consumption_predict)
score.style.background_gradient(cmap ='YlGn', axis = 1,low=0.5, high=0.6)
# Out:
# Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#        'NBEATS', 'NBEATSx'],
#       dtype='object')
# <style type="text/css">
# #T_280d4_row0_col0, #T_280d4_row1_col0, #T_280d4_row2_col0, #T_280d4_row3_col0, #T_280d4_row4_col0 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_280d4_row0_col1, #T_280d4_row1_col1 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_280d4_row0_col2, #T_280d4_row1_col2 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_280d4_row0_col3, #T_280d4_row1_col3 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_280d4_row0_col4, #T_280d4_row1_col4 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_280d4_row0_col5, #T_280d4_row1_col5 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_280d4_row0_col6, #T_280d4_row1_col6, #T_280d4_row2_col6, #T_280d4_row3_col6, #T_280d4_row4_col6 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_280d4_row0_col7, #T_280d4_row1_col7 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_280d4_row2_col1 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_280d4_row2_col2, #T_280d4_row2_col7 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_280d4_row2_col3 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_280d4_row2_col4 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_280d4_row2_col5 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_280d4_row3_col1 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_280d4_row3_col2 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_280d4_row3_col3 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_280d4_row3_col4 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_280d4_row3_col5 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_280d4_row3_col7 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_280d4_row4_col1 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_280d4_row4_col2 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_280d4_row4_col3 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_280d4_row4_col4 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_280d4_row4_col5 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_280d4_row4_col7 {
#   background-color: #b9e294;
#   color: #000000;
# }
# </style>
# <table id="T_280d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_280d4_level0_col0" class="col_heading level0 col0" >GRU</th>
#       <th id="T_280d4_level0_col1" class="col_heading level0 col1" >LSTM</th>
#       <th id="T_280d4_level0_col2" class="col_heading level0 col2" >TCN</th>
#       <th id="T_280d4_level0_col3" class="col_heading level0 col3" >DilatedRNN</th>
#       <th id="T_280d4_level0_col4" class="col_heading level0 col4" >MLP</th>
#       <th id="T_280d4_level0_col5" class="col_heading level0 col5" >NHITS</th>
#       <th id="T_280d4_level0_col6" class="col_heading level0 col6" >NBEATS</th>
#       <th id="T_280d4_level0_col7" class="col_heading level0 col7" >NBEATSx</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_280d4_level0_row0" class="row_heading level0 row0" >mase</th>
#       <td id="T_280d4_row0_col0" class="data row0 col0" >0.569339</td>
#       <td id="T_280d4_row0_col1" class="data row0 col1" >0.744755</td>
#       <td id="T_280d4_row0_col2" class="data row0 col2" >0.822659</td>
#       <td id="T_280d4_row0_col3" class="data row0 col3" >0.638444</td>
#       <td id="T_280d4_row0_col4" class="data row0 col4" >0.759240</td>
#       <td id="T_280d4_row0_col5" class="data row0 col5" >0.583159</td>
#       <td id="T_280d4_row0_col6" class="data row0 col6" >0.968761</td>
#       <td id="T_280d4_row0_col7" class="data row0 col7" >0.650740</td>
#     </tr>
#     <tr>
#       <th id="T_280d4_level0_row1" class="row_heading level0 row1" >mae</th>
#       <td id="T_280d4_row1_col0" class="data row1 col0" >0.061258</td>
#       <td id="T_280d4_row1_col1" class="data row1 col1" >0.080132</td>
#       <td id="T_280d4_row1_col2" class="data row1 col2" >0.088514</td>
#       <td id="T_280d4_row1_col3" class="data row1 col3" >0.068694</td>
#       <td id="T_280d4_row1_col4" class="data row1 col4" >0.081691</td>
#       <td id="T_280d4_row1_col5" class="data row1 col5" >0.062745</td>
#       <td id="T_280d4_row1_col6" class="data row1 col6" >0.104234</td>
#       <td id="T_280d4_row1_col7" class="data row1 col7" >0.070016</td>
#     </tr>
#     <tr>
#       <th id="T_280d4_level0_row2" class="row_heading level0 row2" >mape</th>
#       <td id="T_280d4_row2_col0" class="data row2 col0" >15.308022</td>
#       <td id="T_280d4_row2_col1" class="data row2 col1" >21.804741</td>
#       <td id="T_280d4_row2_col2" class="data row2 col2" >24.603571</td>
#       <td id="T_280d4_row2_col3" class="data row2 col3" >20.118973</td>
#       <td id="T_280d4_row2_col4" class="data row2 col4" >23.460916</td>
#       <td id="T_280d4_row2_col5" class="data row2 col5" >22.128259</td>
#       <td id="T_280d4_row2_col6" class="data row2 col6" >26.571337</td>
#       <td id="T_280d4_row2_col7" class="data row2 col7" >24.593907</td>
#     </tr>
#     <tr>
#       <th id="T_280d4_level0_row3" class="row_heading level0 row3" >rmse</th>
#       <td id="T_280d4_row3_col0" class="data row3 col0" >0.069256</td>
#       <td id="T_280d4_row3_col1" class="data row3 col1" >0.093225</td>
#       <td id="T_280d4_row3_col2" class="data row3 col2" >0.099134</td>
#       <td id="T_280d4_row3_col3" class="data row3 col3" >0.077298</td>
#       <td id="T_280d4_row3_col4" class="data row3 col4" >0.098223</td>
#       <td id="T_280d4_row3_col5" class="data row3 col5" >0.088908</td>
#       <td id="T_280d4_row3_col6" class="data row3 col6" >0.127561</td>
#       <td id="T_280d4_row3_col7" class="data row3 col7" >0.092721</td>
#     </tr>
#     <tr>
#       <th id="T_280d4_level0_row4" class="row_heading level0 row4" >smape</th>
#       <td id="T_280d4_row4_col0" class="data row4 col0" >15.845139</td>
#       <td id="T_280d4_row4_col1" class="data row4 col1" >20.093627</td>
#       <td id="T_280d4_row4_col2" class="data row4 col2" >26.026108</td>
#       <td id="T_280d4_row4_col3" class="data row4 col3" >18.411672</td>
#       <td id="T_280d4_row4_col4" class="data row4 col4" >23.525816</td>
#       <td id="T_280d4_row4_col5" class="data row4 col5" >17.278618</td>
#       <td id="T_280d4_row4_col6" class="data row4 col6" >29.432969</td>
#       <td id="T_280d4_row4_col7" class="data row4 col7" >18.838586</td>
#     </tr>
#   </tbody>
# </table>

# %%
score = data_scaler(score.T)
score.plot(kind='bar', legend=True)
# Out:
# <Axes: >

# %%
results = evaluate_performace(train, test, consumption_predict)
results.to_csv('Data/Neutral_results6.csv')
# Out:
# Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#        'NBEATS', 'NBEATSx'],
#       dtype='object')

# %% [markdown]
# ## Cross_Validate

# %%
cv_df = nf.cross_validation(train,
                            n_windows=3,
                            step_size= 1,
                           )
# Out:
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
cv_df.columns
# Out:
# Index(['unique_id', 'ds', 'cutoff', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN',
#        'MLP', 'NHITS', 'NBEATS', 'NBEATSx', 'Aircon', 'Fridge', 'Garage',
#        'Hotwater', 'HouseBoardOutside', 'HouseBoardOutsideR', 'HouseBoardR',
#        'Import', 'Lights', 'Net', 'OvenStove', 'Powerpoints', 'y', 'temp_c',
#        'is_day', 'wind_kph', 'wind_degree', 'pressure_mb', 'precip_mm',
#        'humidity', 'cloud', 'feelslike_c', 'windchill_c', 'heatindex_c',
#        'dewpoint_c', 'chance_of_rain', 'vis_km', 'gust_kph', 'uv'],
#       dtype='object')

# %%
cv_df.drop('cutoff', axis=1, inplace=True)
cv_df.drop('unique_id', axis=1, inplace=True)

# %%
consumption_predict.columns
# Out:
# Index(['ds', 'RNN', 'GRU', 'LSTM', 'TCN', 'DilatedRNN', 'MLP', 'NHITS',
#        'NBEATS', 'NBEATSx'],
#       dtype='object')

# %%
cv_df_filter = cv_df[consumption_predict.columns]
cv_df_filter.head()
# Out:
#           ds       RNN       GRU      LSTM       TCN  DilatedRNN       MLP  \
# 0 2023-10-11  0.349310  0.365361  0.401426  0.379176    0.384931  0.326775
# 1 2023-10-12  0.360853  0.377349  0.384142  0.383169    0.387812  0.377452
# 2 2023-10-13  0.365891  0.360561  0.330846  0.379273    0.388241  0.352880
# 3 2023-10-14  0.440600  0.430985  0.386927  0.429745    0.445192  0.348349
# 4 2023-10-15  0.414007  0.411958  0.409442  0.380501    0.400195  0.357064
#
#       NHITS    NBEATS   NBEATSx
# 0  0.389734  0.388676  0.384356
# 1  0.383780  0.432581  0.410671
# 2  0.375882  0.392877  0.410011
# 3  0.413572  0.434086  0.456314
# 4  0.387844  0.427270  0.407692

# %%
cv_df_plot = long_form(cv_df_filter)

# %%
cv_df_plot
# Out:
#             ds unique_id         y
# 0   2023-10-11       RNN  0.349310
# 1   2023-10-12       RNN  0.360853
# 2   2023-10-13       RNN  0.365891
# 3   2023-10-14       RNN  0.440600
# 4   2023-10-15       RNN  0.414007
# ..         ...       ...       ...
# 265 2023-10-18   NBEATSx  0.390957
# 266 2023-10-19   NBEATSx  0.334832
# 267 2023-10-20   NBEATSx  0.340729
# 268 2023-10-21   NBEATSx  0.282658
# 269 2023-10-22   NBEATSx  0.410265
#
# [270 rows x 3 columns]

# %%
altair_plot(cv_df_plot)
# Out:
# alt.LayerChart(...)
